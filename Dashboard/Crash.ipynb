# %%
import pandas as pd

# %%
url = ('https://drive.google.com/file/d/1t3Z8Blgy2BPmBB4FqrQkC_jie9IwYuQb/view?usp=sharing')
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
crash_df = pd.read_csv(path,index_col=0)
crash_df
# Out:
#        dvcat    weight   dead  airbag seatbelt  frontal sex  ageOFocc  \
# 1      25-39    25.069  alive    none   belted        1   f        26
# 2      10-24    25.069  alive  airbag   belted        1   f        72
# 3      10-24    32.379  alive    none     none        1   f        69
# 4      25-39   495.444  alive  airbag   belted        1   f        53
# 5      25-39    25.069  alive    none   belted        1   f        32
# ...      ...       ...    ...     ...      ...      ...  ..       ...
# 26213  25-39  3179.688  alive    none   belted        1   m        17
# 26214  10-24    71.228  alive  airbag   belted        1   m        54
# 26215  10-24    10.474  alive  airbag   belted        1   f        27
# 26216  25-39    10.474  alive  airbag   belted        1   f        18
# 26217  25-39    10.474  alive  airbag   belted        1   m        17
#
#        yearacc  yearVeh     abcat occRole  deploy  injSeverity    caseid
# 1         1997   1990.0   unavail  driver       0          3.0     2:3:1
# 2         1997   1995.0    deploy  driver       1          1.0     2:3:2
# 3         1997   1988.0   unavail  driver       0          4.0     2:5:1
# 4         1997   1995.0    deploy  driver       1          1.0    2:10:1
# 5         1997   1988.0   unavail  driver       0          3.0    2:11:1
# ...        ...      ...       ...     ...     ...          ...       ...
# 26213     2002   1985.0   unavail  driver       0          0.0  82:107:1
# 26214     2002   2002.0  nodeploy  driver       0          2.0  82:108:2
# 26215     2002   1990.0    deploy  driver       1          3.0  82:110:1
# 26216     2002   1999.0    deploy  driver       1          0.0  82:110:2
# 26217     2002   1999.0    deploy    pass       1          0.0  82:110:2
#
# [26217 rows x 15 columns]
